# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go 
# import geopandas
import math
import geopy
import geopy.distance
from datetime import datetime
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
locator = geopy.Nominatim(user_agent='myGeocoder')
location = locator.geocode("Nibbles at Pasarbella, Singapore")
coords_1 = (location.latitude, location.longitude)
print('Latitude = {}, Longitude = {}'.format(location.latitude, location.longitude))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-61b089f7b90c> in <module>
#       1 locator = geopy.Nominatim(user_agent='myGeocoder')
#       2 location = locator.geocode("Nibbles at Pasarbella, Singapore")
# ----> 3 coords_1 = (location.latitude, location.longitude)
#       4 print('Latitude = {}, Longitude = {}'.format(location.latitude, location.longitude))
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
coords_2 = (1.301836879239155, 103.85288429942284)
dist = geopy.distance.geodesic(coords_1, coords_2).km

dist
# Out:
# 0.15511246032139697

# %%
df = pd.read_csv('../landmark_locations.csv', index_col=False)
    
df_trunc = df[['Landmark', 'Postal_Code']]

not_in = []
add = []

for i, add in df_trunc.iterrows():
    landmark = add["Landmark"]
    landmark_input = landmark
    if landmark == "Bangladesh High Commission":
        landmark_input = "Keppel Road, Jit Poh Building"
    elif landmark == "Duxton Skybridge":
        landmark_input = "1G Cantonment Rd"
    elif landmark == "MAS Gallery":
        landmark_input = "10 Shenton Way"
    elif landmark == "NUS Baba House":
        landmark_input = "157 Neil Rd"
    elif landmark == "Pin Pin Piau Kay & Co Store":
        landmark_input = "71 Seng Poh Rd" 
    elif landmark == "Holiday Inn Singapore Atrium, Singapore":
        landmark_input = "317 Outram Rd"
    elif landmark == "Beo Crescent Market, Singapore":
        landmark_input = "38A Beo Cres"
    elif landmark == "Tiong Bahru Bird Corner":
        landmark_input = "3 Seng Poh Rd"
    elif landmark == "Qi Tiang Gong Monkey God Temple":
        landmark_input = "44 Eng Hoon St"
    elif landmark == "Hua Bee Restaurant":
        landmark_input = "78 Moh Guan Terrace"
    elif landmark == "Degiosart Gallery":
        landmark_input = "1092 Lower Delta Rd"
    elif landmark == "Bukit Timah Tua Pek Kong Temple":
        landmark_input = "10 Jln Seh Chuan"
    elif landmark == "PasarBella Farmer’s Market":
        landmark_input = "200 Turf Club Rd"
    elif landmark == "Al Azhar Restaurant":
        landmark_input = "11 Cheong Chin Nam Rd"
    elif landmark == "Former Ford Factory":
        landmark_input = "351 Upper Bukit Timah Rd"
    elif landmark == "Singapore Buddhist Lounge":
        landmark_input = "17-19 Kim Yam Rd"
    elif landmark == "Masjid Jamek Queenstown":
        landmark_input = "801 Margaret Dr"
    elif landmark == "Museum of Ice Cream Singapore":
        landmark_input = "100 Loewen Rd"
    elif landmark == "Mei Ling Market & Food Centre":
        landmark_input = "159 Mei Chin Rd"
    elif landmark == "Shuang Long Shan Cemetery":
        landmark_input = "7B Commonwealth Ave"
       
    address = landmark_input + ", Singapore"
    add.append(address)
    
    print(i)
    print(address)
    
    locator = geopy.Nominatim(user_agent='myGeocoder')
    location = locator.geocode(address)
    if(location == None):
        not_in.append([i, address])
        print("not in")
        continue
    coords_1 = (location.latitude, location.longitude)
    
    print(coords_1)
    
df["address"] = add
df
# Out:
# 0
# Buddha Tooth Relic Temple, Singapore
# (1.28150925, 103.84418920262593)
# 1
# Sri Mariamman Temple, Singapore
# (1.2826841500000001, 103.8451939692761)
# 2
# Maxwell Food Centre, Singapore
# (1.28035245, 103.84473966608216)
# 3
# Thian Hock Keng Temple, Singapore
# (1.2814175, 103.8474477)
# 4
# Chinatown Heritage Centre, Singapore
# (1.2834963, 103.8443296)
# 5
# Chinatown Street Market, Singapore
# (1.2799336, 103.8471242)
# 6
# Singapore Musical Box Museum, Singapore
# (1.2807264, 103.8474662)
# 7
# Chinatown Complex, Singapore
# (1.28226875, 103.8431493947401)
# 8
# Masjid Jamae, Singapore
# (1.28316565, 103.84540892274964)
# 9
# People's Park Complex, Singapore
# (1.28413865, 103.84255695900956)
# 10
# Masjid Al-Abrar, Singapore
# (1.2803171, 103.847318)
# 11
# 100 AM, Tras Street, Singapore
# (1.2757664, 103.8439927)
# 12
# Icon Village, Singapore
# (1.2751904, 103.8445374194867)
# 13
# Keppel Road, Jit Poh Building, Singapore
# (1.2729867499999998, 103.84237835)
# 14
# Tanjong Pagar Community Club, Singapore
# (1.2762243, 103.8415498780401)
# 15
# 1G Cantonment Rd, Singapore
# (1.2755656499999999, 103.84130749625815)
# 16
# Jinrikisha Station, Singapore
# (1.2801952, 103.84385727322598)
# 17
# Sri Layan Sithi Vinayagar Temple, Singapore
# (1.28124745, 103.84164520089539)
# 18
# Seng Wong Beo Temple, Singapore
# (1.2756485, 103.844866929175)
# 19
# Guoco Tower, Singapore
# (1.2770467, 103.84547262636721)
# 20
# 10 Shenton Way, Singapore
# (1.27469415, 103.84667718553301)
# 21
# 157 Neil Rd, Singapore
# (1.2771335499999998, 103.83734929172181)
# 22
# Singapore City Gallery, Singapore
# (1.2795017, 103.8451897)
# 23
# Tantric Bar, Singapore
# (1.2796985, 103.8423986)
# 24
# Tiong Bahru Park, Singapore
# (1.2875250999999999, 103.82442515557025)
# 25
# 71 Seng Poh Rd, Singapore
# (1.2842546499999998, 103.8325125)
# 26
# Holiday Inn Singapore Atrium, Singapore
# not in
# 27
# Emerald Park, Singapore
# (1.2896104, 103.83007118745687)
# 28
# Beo Crescent Market, Singapore
# not in
# 29
# Singapore General Hospital, Singapore
# (1.27944885, 103.83627393244066)
# 30
# Foodie Market Place, Singapore
# (1.2834095, 103.8353737)
# 31
# Tan Boon Liat Building, Singapore
# (1.28752175, 103.83402376054374)
# 32
# Tiong Bahru Market, Singapore
# (1.2847764499999998, 103.83254106949653)
# 33
# Tiong Bahru Community Centre, Singapore
# (1.2834636499999998, 103.83190719601991)
# 34
# Tiong Bahru Bird Corner, Singapore
# not in
# 35
# Qi Tiang Gong Monkey God Temple, Singapore
# not in
# 36
# Air Raid Shelter, Singapore
# (1.2834152, 103.8308367)
# 37
# Tiong Bahru Bakery, Singapore
# (1.2844537, 103.8336496)
# 38
# Hua Bee Restaurant, Singapore
# not in
# 39
# Degiosart Gallery, Singapore
# not in
# 40
# Kim Pong Park, Singapore
# (1.283624, 103.82975353790323)
# 41
# Bukit Timah Railway Station, Singapore
# (1.3342290499999998, 103.78114462530877)
# 42
# Bukit Timah Tua Pek Kong Temple, Singapore
# not in
# 43
# Bukit Timah Market & Food Centre, Singapore
# (1.3393921, 103.775951445028)
# 44
# Bukit Timah Nature Reserve, Singapore
# (1.3540779, 103.77944011674754)
# 45
# 100 Turf Club Rd, Singapore
# (1.33423595, 103.79627084790562)
# 46
# PasarBella Farmer’s Market, Singapore
# not in
# 47
# Botanic Gardens, Singapore
# (1.3146320999999999, 103.81561510052387)
# 48
# Al Azhar Restaurant, Singapore
# not in
# 49
# Cluny Court, Singapore
# (1.32262415, 103.81428239213187)
# 50
# Former Ford Factory, Singapore
# not in
# 51
# Singapore Cable Car, Singapore
# (1.2627024, 103.8185034)
# 52
# Henderson Waves Bridge, Singapore
# (1.2761445, 103.8152767)
# 53
# VivoCity, Singapore
# (1.26437065, 103.82295373341057)
# 54
# CHIJ St Theresa's Convent, Singapore
# (1.27614885, 103.8222529475166)
# 55
# Telok Blangah Crescent Market & Food Centre, Singapore
# (1.27738435, 103.81868155000001)
# 56
# Marang Cemetery, Singapore
# (1.2668982999999998, 103.82155559269395)
# 57
# HarbourFront Centre, Singapore
# (1.26422175, 103.82024541611074)
# 58
# St James Power Station, Singapore
# (1.2647482, 103.82482365422536)
# 59
# Hong San See Temple, Singapore
# (1.2933183, 103.8408241)
# 60
# Gateway Theatre, Singapore
# (1.28396515, 103.81655400542637)
# 61
# Chesed-El Synagogue, Singapore
# (1.29725465, 103.84262145371454)
# 62
# Singapore Buddhist Lounge, Singapore
# not in
# 63
# Masjid Jamek Queenstown, Singapore
# not in
# 64
# Amped Trampoline Park, Singapore
# (1.3505743, 103.7288457)
# 65
# Killiney Kopitiam, Singapore
# (1.2988102, 103.8394544)
# 66
# Redhill Market, Singapore
# (1.2878198, 103.81835707350092)
# 67
# Crescent Girls' School, Singapore
# (1.2934392, 103.81802376836586)
# 68
# Museum of Ice Cream Singapore, Singapore
# not in
# 69
# IKEA Alexandra, Singapore
# (1.288488, 103.8059398)
# 70
# Alexandra Village Food Centre, Singapore
# (1.2862946000000002, 103.80449471657035)
# 71
# Alexandra Central Mall, Singapore
# (1.2873524, 103.80525719004731)
# 72
# Mei Ling Market & Food Centre, Singapore
# not in
# 73
# Anchorpoint Shopping Center, Singapore
# not in
# 74
# Margaret Drive Hawker Centre, Singapore
# (1.2974142, 103.8047266)
# 75
# Queenstown Stadium, Singapore
# (1.2959828999999998, 103.80195256646749)
# 76
# Masjid Mujahidin, Singapore
# (1.2981506999999999, 103.80095879305927)
# 77
# Tanglin Halt Market, Singapore
# (1.3005357, 103.7977552)
# 78
# SkyVille @ Dawson, Singapore
# (1.2957727, 103.80984878910313)
# 79
# Queenstown Lutheran Church, Singapore
# (1.3062871, 103.7992088)
# 80
# Alexandra Hospital, Singapore
# (1.2867939000000002, 103.8011060599271)
# 81
# Skybridge @ Queen’s Close, Singapore
# not in
# 82
# Queenstown ActiveSG Swimming Complex, Singapore
# not in
# 83
# Queensway Shopping Centre, Singapore
# (1.28750595, 103.8035434807163)
# 84
# Holland Drive Market and Food Centre, Singapore
# (1.3081903, 103.7930252)
# 85
# Singapore Post Office Ghim Moh, Singapore
# not in
# 86
# MOE HQ, Singapore
# not in
# 87
# Buona Vista Community Club, Singapore
# (1.3092541500000001, 103.79262395132965)
# 88
# Shuang Long Shan Cemetery, Singapore
# not in
# 89
# Ulu Pandan Community Club, Singapore
# (1.3121632, 103.78974075344829)
# 90
# ACS International, Singapore
# (1.3076940000000001, 103.7980388566955)
# 91
# Ghim Moh Road Market & Food Centre, Singapore
# not in

# %%
print(not_in)
# Out:
# [[26, 'Holiday Inn Singapore Atrium, Singapore'], [28, 'Beo Crescent Market, Singapore'], [34, 'Tiong Bahru Bird Corner, Singapore'], [35, 'Qi Tiang Gong Monkey God Temple, Singapore'], [38, 'Hua Bee Restaurant, Singapore'], [39, 'Degiosart Gallery, Singapore'], [42, 'Bukit Timah Tua Pek Kong Temple, Singapore'], [46, 'PasarBella Farmer’s Market, Singapore'], [48, 'Al Azhar Restaurant, Singapore'], [50, 'Former Ford Factory, Singapore'], [62, 'Singapore Buddhist Lounge, Singapore'], [63, 'Masjid Jamek Queenstown, Singapore'], [68, 'Museum of Ice Cream Singapore, Singapore'], [72, 'Mei Ling Market & Food Centre, Singapore'], [73, 'Anchorpoint Shopping Center, Singapore'], [81, 'Skybridge @ Queen’s Close, Singapore'], [82, 'Queenstown ActiveSG Swimming Complex, Singapore'], [85, 'Singapore Post Office Ghim Moh, Singapore'], [86, 'MOE HQ, Singapore'], [88, 'Shuang Long Shan Cemetery, Singapore'], [91, 'Ghim Moh Road Market & Food Centre, Singapore']]
